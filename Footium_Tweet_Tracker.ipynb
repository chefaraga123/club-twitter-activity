# %% [markdown]
# # STEP 1: Fetch & Structure Tweet Data
# ### Goal: Get the latest tweets, enrich them with metadata, and append them to the historical record.
#
# API Query 1: Fetch the latest 100 tweets from a specific Twitter list.
#
# API Query 2: For each tweet, fetch public metrics (likes, replies, impressions) and author details.
#
# Convert tweet timestamps into datetime format.
#
# Combine these new tweets with a historical CSV to maintain a growing dataset of all tweets.
#
# Save the full, deduplicated, chronologically sorted dataset to a new CSV file (e.g. 02_04_2025.csv).
#
# # STEP 2: Map Tweets to Game Seasons & Aggregate Stats
# ### Goal: Attribute each tweet to a game season, and summarize engagement metrics per author.
#
# Define a calendar of game seasons (e.g. Season 4, Season 5, Season 6) using start and end dates.
#
# Convert each tweet’s timestamp and map it to the correct season.
#
# Filter out tweets that fall outside of any season.
#
# Group by season_label and author_username to aggregate:
# - tweet_count
# - like_count
# - impression_count
# - reply_count
#
# Save this aggregated view to a CSV file (e.g. season_aggregated_tweets_02_04_2025.csv).
#
# # STEP 3: Publish to Notion
# ### Goal: Upload the season-by-season summary into a Notion database for easy viewing or sharing.
#
# - Load the aggregated CSV (one row per author per season).
# - For each row, create a new page in Notion via the API.
#
# ### Each page includes:
# - season_label as the title
# - author_username as rich text
# - All public metrics as number fields
# - A placeholder Season Impressions Rank field (can be calculated later)
#
# - Log each entry creation to the console for tracking.

# %%
'''
STEP 1 
- API Query 1: Get the 100 most recent tweets by looking at the Twitter list.
- API Query 2: For each of those 100 tweets use the id to query the endpoint to get the public metrics for each of those tweets:.
- Convert the entries in the timestamp column to date-time
- The **newly created dataframe** (the way in which the tweets record is structured) is **combined with the historical one** to get a combined dataframe.
'''

import os
import requests
import json
import pandas as pd
import time
from datetime import datetime
from dotenv import load_dotenv


load_dotenv()

BEARER_TOKEN = os.getenv("BEARER_TOKEN")
HEADERS = {"Authorization": f"Bearer {BEARER_TOKEN}"}


'''
- Fetches the most recent 100 tweets
'''
def fetch_tweets():
    url = "https://api.x.com/2/lists/1651199577985261569/tweets"
    querystring = {"max_results": "100"}

    response = requests.get(url, headers=HEADERS, params=querystring)

    if response.status_code == 200:
        data = response.json()
        df = pd.DataFrame(data.get("data", []))
        return df


'''
- Takes in all the tweets and gets their IDs
- For each tweet 
'''
def get_context_from_post(tweets):
    """Fetch author ID and public metrics from tweet ID"""

    tweet_ids = list(tweets['id'])
    ids_string = ",".join(tweet_ids)

    querystring = {
        "ids": ids_string,
        "tweet.fields": "author_id,public_metrics,created_at"  # Include additional fields as needed
    }

    response = requests.get(
        "https://api.x.com/2/tweets", 
        headers=HEADERS, 
        params=querystring
    )

    context_data = response.json()

    # Creates a new CSV with all the context 
    context_df = pd.DataFrame(context_data['data'])

    df_metrics = context_df['public_metrics'].apply(pd.Series)
    
    context_df.drop(columns=['public_metrics'], inplace=True)

    context_df = context_df.join(df_metrics, how="inner")

    author_ids = []
    for tweet in response.json().get("data", []):
        author_ids.append(tweet.get("author_id"))

    author_ids_string = ",".join(author_ids)

    author_querystring = {
        "ids": author_ids_string,
        "user.fields": "username"
    }
    author_response = requests.get(
        "https://api.x.com/2/users", 
        headers=HEADERS, 
        params=author_querystring
    )

    author_data = author_response.json()
    author_data = author_data['data']

    # Create a DataFrame from the extracted data
    author_df = pd.DataFrame(author_data)

    # Rename the column 'old_name' to 'new_name'
    author_df.rename(columns={'id': 'author_id'}, inplace=True)

    # Joins the author dataframe and the the tweet context dataframe on the author_id
    merged_df = pd.merge(author_df, context_df, left_on='author_id', right_on='author_id', how='inner')

    # Drop irrelevant data 
    merged_df.drop(['name', 'bookmark_count'], axis=1, inplace=True)

    # Updates the name for consistency
    merged_df.rename(columns={'username': 'author_username'}, inplace=True)

    merged_df['edit_history_tweet_ids'] = merged_df['edit_history_tweet_ids'].apply(tuple)
    merged_df.drop_duplicates(inplace=True)

    # Creates a new CSV with the 100 latest tweets and their context 
    merged_df.to_csv("test.csv", index=False)
    
    return merged_df

# Returns a dataframe with three columns: id, edit_history_tweet_ids, text
tweets = fetch_tweets()
# Passes the tweets forward to get their context 
processed_tweets = get_context_from_post(tweets)
# Ensure that the recently updated tweets have the same columns 


'''
This should be maintained so that there is a seperate CSV for each season as well as a CSV containing the global history - for the purposes of pushing to Notion we only want the current season.
'''

# takes ina CSV used as df_bottom
df = pd.read_csv('latest.csv')
processed_tweets = processed_tweets[df.columns]

# Concatenate dataframes with the top one first
df_combined = pd.concat([processed_tweets, df], ignore_index=True)

# Drop duplicates 
df_combined_no_duplicates = df_combined.drop_duplicates()

# Convert the timestamp column to datetime
df_combined_no_duplicates['created_at'] = pd.to_datetime(df_combined_no_duplicates['created_at'], errors='coerce')

df_combined_no_duplicates.sort_values("created_at", ascending=False, inplace=True)

# Save the combined dataframe to a new CSV file
df_combined_no_duplicates.to_csv("02_04_2025.csv", index=False)

# %%
'''
STEP 2
- Define game seasons so that each tweet can be attributed as occuring within a particular game season
- Aggregate the tweet data, to get the tweet counts and public engagement metrics per author per season
- Save the output 
'''

import pandas as pd

csv_file_path = "season6_02_04.csv"  # Replace with actual CSV path
df = pd.read_csv(csv_file_path)

# Check the product calendar to update when there are new seasons.  
game_seasons = [
    {"season_name": "Season 4", "start_date": "2025-01-21", "end_date": "2025-02-19"},
    {"season_name": "Season 5", "start_date": "2025-02-20", "end_date": "2025-03-18"},
    {"season_name": "Season 6", "start_date": "2025-03-25", "end_date": "2025-04-23"},
]

# Convert to DataFrame for easier handling
seasons_df = pd.DataFrame(game_seasons)
seasons_df["start_date"] = pd.to_datetime(seasons_df["start_date"])
seasons_df["end_date"] = pd.to_datetime(seasons_df["end_date"])

# Function to get season for a given date
def get_season(timestamp):
    for _, row in seasons_df.iterrows():
        if row["start_date"] <= timestamp <= row["end_date"]:
            return row["season_name"]
    return "Out of Season"

# Ensure created_at is in datetime format
df["created_at"] = pd.to_datetime(df["created_at"], errors="coerce")
df["created_at"] = df["created_at"].dt.tz_localize(None)

# Check for any rows where created_at could not be parsed
if df["created_at"].isna().sum() > 0:
    print("Warning: Some timestamps could not be parsed. They will be dropped.")

# Drop rows with invalid timestamps
df = df.dropna(subset=["created_at"])

# Map tweets to their season
df["season_label"] = df["created_at"].apply(get_season)

# Drop out-of-season tweets if desired
df = df[df["season_label"] != "Out of Season"]

# Add tweet count
df["tweet_count"] = 1

# Aggregate by season
agg_df = df.groupby(["season_label", "author_username"]).agg(
    tweet_count=("tweet_count", "sum"),
    like_count=("like_count", "sum"),
    impression_count=("impression_count", "sum"),
    reply_count=("reply_count", "sum")
).reset_index()

# Output
agg_df.to_csv("season_aggregated_tweets_02_04_2025.csv", index=False)

# %%
'''
STEP 3
- Load the aggregated tweet data from CSV
- For each row (author x season), create a new page in a Notion database
- Each page includes tweet and engagement metrics (impressions, likes, replies) along with metadata like season and author
'''

import pandas as pd 
import requests
import json
from dotenv import load_dotenv
load_dotenv()
NOTION_API_KEY = os.getenv("NOTION_API")

headers = {
    "Authorization": f"Bearer {NOTION_API_KEY}",
    "Notion-Version": "2022-06-28",
    "Content-Type": "application/json",
}

Empty_DB_ID = "1c28ce2d7cac8099ae7ff0c52bb6ed6b"

'''
This CSV needs to contain all the aggregations for the latest season 
'''
csv_file_path = "season_aggregated_tweets_02_04_2025.csv"  
df = pd.read_csv(csv_file_path)


# 🔹 Extract & Prepare Data
for _, row in df.iterrows():
    new_entry = {
        "parent": {"database_id": Empty_DB_ID},
            "properties": {
                "season_label": {
                    "title": [{"text": {"content": row["season_label"]}}]
                },
                "Season Impressions Rank": {"number": 0},

                "author_username": {
                    "rich_text": [{"text": {"content": row["author_username"]}}]
                },
                "tweet_count": {"number": row["tweet_count"]},
                "impression_count": {"number": row["impression_count"]},
                "like_count": {"number": row["like_count"]},
                "reply_count": {"number": row["reply_count"]}
            },
    }

    # Log to the console to see what its being updated to notion 
    print(new_entry) 

    # 🔹 Send request to create a new Notion page
    url = "https://api.notion.com/v1/pages"
    response = requests.post(url, headers=headers, json=new_entry)

    # Print response (check if the row has been successfully added)
    print(f"Added {row['author_username']} - {row['season_label']} → {response.text}")
# Out:
# 32
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': '2026bear'}}]}, 'tweet_count': {'number': 4}, 'impression_count': {'number': 0.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 0.0}}}
# Added 2026bear - Season 6 → {"object":"page","id":"1c98ce2d-7cac-8103-96c7-d64dfd39aa61","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":4},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"2026bear","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"2026bear","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":0},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac810396c7d64dfd39aa61","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac810396c7d64dfd39aa61","request_id":"eca05715-82ab-43e7-8418-f7d664493f4d"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'AshamForon'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 11.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 0.0}}}
# Added AshamForon - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81ab-9af9-c14de5e11dc3","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"AshamForon","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"AshamForon","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":11},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81ab9af9c14de5e11dc3","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81ab9af9c14de5e11dc3","request_id":"ca0c1063-a27a-4f0d-a19b-cd3b2f82ea84"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'BraunborCity'}}]}, 'tweet_count': {'number': 3}, 'impression_count': {'number': 270.0}, 'like_count': {'number': 17.0}, 'reply_count': {'number': 1.0}}}
# Added BraunborCity - Season 6 → {"object":"page","id":"1c98ce2d-7cac-812c-b6c5-f3e2e131c672","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":3},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"BraunborCity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"BraunborCity","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":270},"reply_count":{"id":"svxe","type":"number","number":1},"like_count":{"id":"u%60%7CF","type":"number","number":17},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac812cb6c5f3e2e131c672","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac812cb6c5f3e2e131c672","request_id":"89f2fcff-b4e8-4d45-a500-8eea9709186f"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'CarthFC'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 23.0}, 'like_count': {'number': 2.0}, 'reply_count': {'number': 0.0}}}
# Added CarthFC - Season 6 → {"object":"page","id":"1c98ce2d-7cac-8186-936c-fac270b371a9","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"CarthFC","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"CarthFC","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":23},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":2},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac8186936cfac270b371a9","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac8186936cfac270b371a9","request_id":"d0ce5f7d-0646-4c34-8937-89a53b250313"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'CoroadBrains'}}]}, 'tweet_count': {'number': 25}, 'impression_count': {'number': 1958.0}, 'like_count': {'number': 120.0}, 'reply_count': {'number': 14.0}}}
# Added CoroadBrains - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81b4-95a5-c8311ef249a2","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":25},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"CoroadBrains","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"CoroadBrains","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":1958},"reply_count":{"id":"svxe","type":"number","number":14},"like_count":{"id":"u%60%7CF","type":"number","number":120},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81b495a5c8311ef249a2","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81b495a5c8311ef249a2","request_id":"ae22b26f-ec41-468d-b4ef-24250dddcc92"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'CroutheSeaton'}}]}, 'tweet_count': {'number': 2}, 'impression_count': {'number': 38.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 0.0}}}
# Added CroutheSeaton - Season 6 → {"object":"page","id":"1c98ce2d-7cac-815d-8ee1-dfd7dfee8ec6","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":2},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"CroutheSeaton","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"CroutheSeaton","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":38},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac815d8ee1dfd7dfee8ec6","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac815d8ee1dfd7dfee8ec6","request_id":"a2e2cde6-2c09-4b4d-9c15-d1270ac3f4c7"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'DagefielFC'}}]}, 'tweet_count': {'number': 4}, 'impression_count': {'number': 19.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 3.0}}}
# Added DagefielFC - Season 6 → {"object":"page","id":"1c98ce2d-7cac-817d-8ff5-ffad3035ee27","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":4},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"DagefielFC","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"DagefielFC","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":19},"reply_count":{"id":"svxe","type":"number","number":3},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac817d8ff5ffad3035ee27","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac817d8ff5ffad3035ee27","request_id":"d2e62d56-1774-4158-951f-3d6bf9574314"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'EaryBeccley'}}]}, 'tweet_count': {'number': 13}, 'impression_count': {'number': 212.0}, 'like_count': {'number': 13.0}, 'reply_count': {'number': 9.0}}}
# Added EaryBeccley - Season 6 → {"object":"page","id":"1c98ce2d-7cac-8103-9f08-d3ac49b73247","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":13},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"EaryBeccley","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"EaryBeccley","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":212},"reply_count":{"id":"svxe","type":"number","number":9},"like_count":{"id":"u%60%7CF","type":"number","number":13},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81039f08d3ac49b73247","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81039f08d3ac49b73247","request_id":"2331aec6-85ca-48dd-b0e5-1fd5422ff2f5"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'FlinninFC'}}]}, 'tweet_count': {'number': 6}, 'impression_count': {'number': 302.0}, 'like_count': {'number': 21.0}, 'reply_count': {'number': 1.0}}}
# Added FlinninFC - Season 6 → {"object":"page","id":"1c98ce2d-7cac-810a-9dce-e0a1513cd183","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":6},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"FlinninFC","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"FlinninFC","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":302},"reply_count":{"id":"svxe","type":"number","number":1},"like_count":{"id":"u%60%7CF","type":"number","number":21},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac810a9dcee0a1513cd183","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac810a9dcee0a1513cd183","request_id":"2168f913-d8fc-42c1-9473-6ccc42d2e5aa"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'FootiumMik'}}]}, 'tweet_count': {'number': 10}, 'impression_count': {'number': 1383.0}, 'like_count': {'number': 43.0}, 'reply_count': {'number': 7.0}}}
# Added FootiumMik - Season 6 → {"object":"page","id":"1c98ce2d-7cac-8105-bd79-dd9ec3ba281b","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":10},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"FootiumMik","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"FootiumMik","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":1383},"reply_count":{"id":"svxe","type":"number","number":7},"like_count":{"id":"u%60%7CF","type":"number","number":43},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac8105bd79dd9ec3ba281b","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac8105bd79dd9ec3ba281b","request_id":"c921a0ca-e8b6-456c-bd7f-680ae2b06a0f"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'GreekFootium'}}]}, 'tweet_count': {'number': 7}, 'impression_count': {'number': 1143.0}, 'like_count': {'number': 24.0}, 'reply_count': {'number': 2.0}}}
# Added GreekFootium - Season 6 → {"object":"page","id":"1c98ce2d-7cac-8181-8bc3-f05108a4591c","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":7},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"GreekFootium","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"GreekFootium","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":1143},"reply_count":{"id":"svxe","type":"number","number":2},"like_count":{"id":"u%60%7CF","type":"number","number":24},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81818bc3f05108a4591c","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81818bc3f05108a4591c","request_id":"3f0f7eef-9022-4611-9c9a-aaa251625f06"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'HedgeSportsGROU'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 157.0}, 'like_count': {'number': 11.0}, 'reply_count': {'number': 2.0}}}
# Added HedgeSportsGROU - Season 6 → {"object":"page","id":"1c98ce2d-7cac-8128-8e4f-c6c20acc1aab","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"HedgeSportsGROU","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"HedgeSportsGROU","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":157},"reply_count":{"id":"svxe","type":"number","number":2},"like_count":{"id":"u%60%7CF","type":"number","number":11},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81288e4fc6c20acc1aab","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81288e4fc6c20acc1aab","request_id":"a8e6f597-182a-4f20-969f-ab34c4482e9c"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'HellankroughFC'}}]}, 'tweet_count': {'number': 4}, 'impression_count': {'number': 283.0}, 'like_count': {'number': 15.0}, 'reply_count': {'number': 1.0}}}
# Added HellankroughFC - Season 6 → {"object":"page","id":"1c98ce2d-7cac-8184-8493-db3676a64b7a","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":4},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"HellankroughFC","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"HellankroughFC","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":283},"reply_count":{"id":"svxe","type":"number","number":1},"like_count":{"id":"u%60%7CF","type":"number","number":15},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81848493db3676a64b7a","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81848493db3676a64b7a","request_id":"8b94af03-cce2-42f3-a710-e2321e6eac68"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'Hornseaffor'}}]}, 'tweet_count': {'number': 2}, 'impression_count': {'number': 1729.0}, 'like_count': {'number': 25.0}, 'reply_count': {'number': 3.0}}}
# Added Hornseaffor - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81e0-9b12-ead63845ee99","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":2},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"Hornseaffor","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Hornseaffor","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":1729},"reply_count":{"id":"svxe","type":"number","number":3},"like_count":{"id":"u%60%7CF","type":"number","number":25},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81e09b12ead63845ee99","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81e09b12ead63845ee99","request_id":"acf1eca8-4b82-409b-ada9-cf21d6664548"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'IvyburnFC'}}]}, 'tweet_count': {'number': 9}, 'impression_count': {'number': 855.0}, 'like_count': {'number': 58.0}, 'reply_count': {'number': 2.0}}}
# Added IvyburnFC - Season 6 → {"object":"page","id":"1c98ce2d-7cac-810f-a889-c5ccceaea29e","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":9},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"IvyburnFC","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"IvyburnFC","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":855},"reply_count":{"id":"svxe","type":"number","number":2},"like_count":{"id":"u%60%7CF","type":"number","number":58},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac810fa889c5ccceaea29e","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac810fa889c5ccceaea29e","request_id":"e6a1e853-8d0e-45f4-969d-95abf8e59647"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'KingtonParkFC'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 70.0}, 'like_count': {'number': 3.0}, 'reply_count': {'number': 0.0}}}
# Added KingtonParkFC - Season 6 → {"object":"page","id":"1c98ce2d-7cac-814e-aaf6-caade2827580","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"KingtonParkFC","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"KingtonParkFC","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":70},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":3},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac814eaaf6caade2827580","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac814eaaf6caade2827580","request_id":"5c9db5c3-4b05-4f96-ad77-99900eec8d30"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'LingRovers'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 0.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 0.0}}}
# Added LingRovers - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81a8-aa72-c8ecc9335842","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"LingRovers","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"LingRovers","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":0},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81a8aa72c8ecc9335842","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81a8aa72c8ecc9335842","request_id":"d5a22067-39ad-43f8-bea9-37bbb902d8fd"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'LoughParkfc'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 0.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 0.0}}}
# Added LoughParkfc - Season 6 → {"object":"page","id":"1c98ce2d-7cac-8178-95d5-ecf1b197b2e8","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"LoughParkfc","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"LoughParkfc","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":0},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac817895d5ecf1b197b2e8","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac817895d5ecf1b197b2e8","request_id":"bf9693a0-d6e7-49d9-80ef-3aa03bc0e1cd"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'MandCronAshamFC'}}]}, 'tweet_count': {'number': 16}, 'impression_count': {'number': 1040.0}, 'like_count': {'number': 36.0}, 'reply_count': {'number': 4.0}}}
# Added MandCronAshamFC - Season 6 → {"object":"page","id":"1c98ce2d-7cac-816d-a334-ee0f2b4b2853","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":16},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"MandCronAshamFC","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"MandCronAshamFC","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":1040},"reply_count":{"id":"svxe","type":"number","number":4},"like_count":{"id":"u%60%7CF","type":"number","number":36},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac816da334ee0f2b4b2853","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac816da334ee0f2b4b2853","request_id":"482c41e2-790c-4c2f-b3ca-596b47c73606"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'MantowOG'}}]}, 'tweet_count': {'number': 4}, 'impression_count': {'number': 88.0}, 'like_count': {'number': 6.0}, 'reply_count': {'number': 0.0}}}
# Added MantowOG - Season 6 → {"object":"page","id":"1c98ce2d-7cac-813a-be9c-e91fe138eafa","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":4},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"MantowOG","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"MantowOG","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":88},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":6},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac813abe9ce91fe138eafa","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac813abe9ce91fe138eafa","request_id":"979c7822-6bdb-4454-b185-1877d924039b"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'MarrouckVilla'}}]}, 'tweet_count': {'number': 17}, 'impression_count': {'number': 2015.0}, 'like_count': {'number': 69.0}, 'reply_count': {'number': 17.0}}}
# Added MarrouckVilla - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81ab-af58-ff6915b1c6c7","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":17},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"MarrouckVilla","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"MarrouckVilla","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":2015},"reply_count":{"id":"svxe","type":"number","number":17},"like_count":{"id":"u%60%7CF","type":"number","number":69},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81abaf58ff6915b1c6c7","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81abaf58ff6915b1c6c7","request_id":"49a861a0-b503-498c-bfef-64448ae6e214"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'MarwickCF'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 0.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 0.0}}}
# Added MarwickCF - Season 6 → {"object":"page","id":"1c98ce2d-7cac-812d-904a-c84d27b3ce82","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"MarwickCF","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"MarwickCF","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":0},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac812d904ac84d27b3ce82","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac812d904ac84d27b3ce82","request_id":"d5bb98da-bea4-4360-9bc6-7fdef684dcfe"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'OldseaStanley'}}]}, 'tweet_count': {'number': 20}, 'impression_count': {'number': 2191.0}, 'like_count': {'number': 74.0}, 'reply_count': {'number': 14.0}}}
# Added OldseaStanley - Season 6 → {"object":"page","id":"1c98ce2d-7cac-814b-8abe-ebc54e5aafe9","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":20},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"OldseaStanley","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"OldseaStanley","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":2191},"reply_count":{"id":"svxe","type":"number","number":14},"like_count":{"id":"u%60%7CF","type":"number","number":74},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac814b8abeebc54e5aafe9","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac814b8abeebc54e5aafe9","request_id":"c785cbbd-87b8-4649-9c3a-e5624230b2eb"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'P16KUP'}}]}, 'tweet_count': {'number': 3}, 'impression_count': {'number': 262.0}, 'like_count': {'number': 9.0}, 'reply_count': {'number': 0.0}}}
# Added P16KUP - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81bb-a564-d35469319962","created_time":"2025-04-02T09:01:00.000Z","last_edited_time":"2025-04-02T09:01:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":3},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"P16KUP","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"P16KUP","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":262},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":9},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81bba564d35469319962","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81bba564d35469319962","request_id":"1bcba59d-4bc4-45ec-905f-837aaef17138"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'PenCityFC'}}]}, 'tweet_count': {'number': 11}, 'impression_count': {'number': 2528.0}, 'like_count': {'number': 74.0}, 'reply_count': {'number': 6.0}}}
# ...
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'WitbyUnited'}}]}, 'tweet_count': {'number': 3}, 'impression_count': {'number': 89.0}, 'like_count': {'number': 5.0}, 'reply_count': {'number': 0.0}}}
# Added WitbyUnited - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81ed-b685-c81e12fa130a","created_time":"2025-04-02T09:02:00.000Z","last_edited_time":"2025-04-02T09:02:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":3},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"WitbyUnited","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"WitbyUnited","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":89},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":5},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81edb685c81e12fa130a","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81edb685c81e12fa130a","request_id":"c21968a2-ec84-41f1-a707-9803713ab991"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'WoldWanderers'}}]}, 'tweet_count': {'number': 2}, 'impression_count': {'number': 0.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 0.0}}}
# Added WoldWanderers - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81fa-a57d-d27a329bb6cf","created_time":"2025-04-02T09:02:00.000Z","last_edited_time":"2025-04-02T09:02:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":2},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"WoldWanderers","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"WoldWanderers","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":0},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81faa57dd27a329bb6cf","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81faa57dd27a329bb6cf","request_id":"c9a676c6-0b84-436e-b6a9-d5256a408c8d"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'cheackippleigh'}}]}, 'tweet_count': {'number': 18}, 'impression_count': {'number': 1849.0}, 'like_count': {'number': 89.0}, 'reply_count': {'number': 11.0}}}
# Added cheackippleigh - Season 6 → {"object":"page","id":"1c98ce2d-7cac-811f-aa11-c3d289cbec1d","created_time":"2025-04-02T09:02:00.000Z","last_edited_time":"2025-04-02T09:02:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":18},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"cheackippleigh","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"cheackippleigh","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":1849},"reply_count":{"id":"svxe","type":"number","number":11},"like_count":{"id":"u%60%7CF","type":"number","number":89},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac811faa11c3d289cbec1d","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac811faa11c3d289cbec1d","request_id":"820ea642-be74-4578-b977-647b9eba5488"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'cownhamptonFC'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 0.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 0.0}}}
# Added cownhamptonFC - Season 6 → {"object":"page","id":"1c98ce2d-7cac-815f-a0e1-f98a0a03c65d","created_time":"2025-04-02T09:02:00.000Z","last_edited_time":"2025-04-02T09:02:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"cownhamptonFC","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"cownhamptonFC","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":0},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac815fa0e1f98a0a03c65d","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac815fa0e1f98a0a03c65d","request_id":"80d1c5b7-143d-4ba7-908d-a7503ae63f32"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'elshborparkfc'}}]}, 'tweet_count': {'number': 9}, 'impression_count': {'number': 449.0}, 'like_count': {'number': 23.0}, 'reply_count': {'number': 3.0}}}
# Added elshborparkfc - Season 6 → {"object":"page","id":"1c98ce2d-7cac-816e-8340-d9fd193320f1","created_time":"2025-04-02T09:02:00.000Z","last_edited_time":"2025-04-02T09:02:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":9},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"elshborparkfc","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"elshborparkfc","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":449},"reply_count":{"id":"svxe","type":"number","number":3},"like_count":{"id":"u%60%7CF","type":"number","number":23},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac816e8340d9fd193320f1","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac816e8340d9fd193320f1","request_id":"add6a7b5-45cd-4b86-8c2d-12ba645f3554"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'minge_fc'}}]}, 'tweet_count': {'number': 2}, 'impression_count': {'number': 8.0}, 'like_count': {'number': 0.0}, 'reply_count': {'number': 1.0}}}
# Added minge_fc - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81be-a563-c02b16cdb06a","created_time":"2025-04-02T09:02:00.000Z","last_edited_time":"2025-04-02T09:02:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":2},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"minge_fc","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"minge_fc","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":8},"reply_count":{"id":"svxe","type":"number","number":1},"like_count":{"id":"u%60%7CF","type":"number","number":0},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81bea563c02b16cdb06a","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81bea563c02b16cdb06a","request_id":"172f7bd0-43eb-4907-b4a7-eaeda7169a94"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'shrawenfc'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 48.0}, 'like_count': {'number': 1.0}, 'reply_count': {'number': 0.0}}}
# Added shrawenfc - Season 6 → {"object":"page","id":"1c98ce2d-7cac-8161-91a3-e94a4f120656","created_time":"2025-04-02T09:02:00.000Z","last_edited_time":"2025-04-02T09:02:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"shrawenfc","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"shrawenfc","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":48},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":1},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac816191a3e94a4f120656","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac816191a3e94a4f120656","request_id":"ae5cd8c2-fc40-4580-8bb1-90dcb20a1b40"}
# {'parent': {'database_id': '1c28ce2d7cac8099ae7ff0c52bb6ed6b'}, 'properties': {'season_label': {'title': [{'text': {'content': 'Season 6'}}]}, 'Season Impressions Rank': {'number': 0}, 'author_username': {'rich_text': [{'text': {'content': 'westonparkfc'}}]}, 'tweet_count': {'number': 1}, 'impression_count': {'number': 80.0}, 'like_count': {'number': 2.0}, 'reply_count': {'number': 0.0}}}
# Added westonparkfc - Season 6 → {"object":"page","id":"1c98ce2d-7cac-81bb-a5a4-d34bf335651d","created_time":"2025-04-02T09:02:00.000Z","last_edited_time":"2025-04-02T09:02:00.000Z","created_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"last_edited_by":{"object":"user","id":"426970d2-a467-4280-aa05-8f342f45853e"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"1c28ce2d-7cac-8099-ae7f-f0c52bb6ed6b"},"archived":false,"in_trash":false,"properties":{"tweet_count":{"id":"%3BRZ%5D","type":"number","number":1},"author_username":{"id":"B%3F%40j","type":"rich_text","rich_text":[{"type":"text","text":{"content":"westonparkfc","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"westonparkfc","href":null}]},"Season Impressions Rank":{"id":"Ni%7DE","type":"number","number":0},"impression_count":{"id":"ffXB","type":"number","number":80},"reply_count":{"id":"svxe","type":"number","number":0},"like_count":{"id":"u%60%7CF","type":"number","number":2},"season_label":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Season 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Season 6","href":null}]}},"url":"https://www.notion.so/Season-6-1c98ce2d7cac81bba5a4d34bf335651d","public_url":"https://footiumofficial.notion.site/Season-6-1c98ce2d7cac81bba5a4d34bf335651d","request_id":"8068e701-56c7-4602-a911-f2bc67c1fb15"}

# %%
'''
Aggregates on each week
'''

#Generates a CSV containing the aggregated tweets for each week on record - redundant now that we're looking at seasons rather than weeks 
import pandas as pd

csv_file_path = "latest.csv"  # Replace with actual CSV path
df = pd.read_csv(csv_file_path)

# Ensure created_at is in datetime format
df["created_at"] = pd.to_datetime(df["created_at"], errors="coerce")

# Check for any rows where created_at could not be parsed
if df["created_at"].isna().sum() > 0:
    print("Warning: Some timestamps could not be parsed. They will be dropped.")

# Drop rows with invalid timestamps
df = df.dropna(subset=["created_at"])

# 🔹 Convert 'created_at' to 'week_label' (Monday Start of Week)
df["week_label"] = pd.to_datetime(df["created_at"]).dt.to_period("W").apply(lambda x: x.start_time.date().strftime('%Y-%m-%d'))

df = df[df["author_username"] != "Footium"]

# 🔹 Add a Tweet Count Column (Each row represents one tweet)
df["tweet_count"] = 1

# 🔹 Aggregate Data
agg_df = df.groupby(["week_label", "author_username"]).agg(
    tweet_count=("tweet_count", "sum"),
    like_count=("like_count", "sum"),
    impression_count=("impression_count", "sum"),
    reply_count=("reply_count", "sum")
).reset_index()

agg_df.to_csv("weekly_aggregated_tweets.csv", index=False)
# Out:
# Warning: Some timestamps could not be parsed. They will be dropped.
# C:\Users\james\AppData\Local\Temp\ipykernel_39988\2141542210.py:18: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["week_label"] = pd.to_datetime(df["created_at"]).dt.to_period("W").apply(lambda x: x.start_time.date().strftime('%Y-%m-%d'))
